# %%
import cv2
import numpy as np
import tensorflow as tf
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Flatten
from keras.utils import to_categorical
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Dropout
from PIL import Image
from keras.preprocessing import image

# %%
def train_model_base(model, x_train, y_train, x_test, y_test, epochs=100, batch_size=200):
    y_train = to_categorical(y_train)
    y_test = to_categorical(y_test)
    model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_split=0.2, # Доля валидационной выборки для контроля переобучения
              verbose=2) #verbose=0 ничего не покажет, verbose=1 покажет анимированный индикатор выполнения (progress_bar), verbose=2 будет просто указать номер эпохи

# %%
def predict_dense_base(model, img):
    print("shape:", img.shape)  # Добавим вывод формы входных данных
    # Получаем вероятности для каждого класса
    probabilities = model.predict(img)
    # Используем argmax для получения индекса класса с наибольшей вероятностью
    return np.argmax(probabilities)

# %%
def print_metrics_base(model):
    history_dict = model.history.history
    best_epoch = np.argmax(history_dict['val_accuracy']) + 1

    print("Метрики обучения:")
    print("---------------------------------------------------------")
    print(f"Максимальная точность на тренировочном наборе: {max(history_dict['accuracy']):.4f}")
    print(f"Минимальная потеря на тренировочном наборе: {min(history_dict['loss']):.4f}")
    print(f"Максимальная точность на валидационном наборе: {max(history_dict['val_accuracy']):.4f}")
    print(f"Минимальная потеря на валидационном наборе: {min(history_dict['val_loss']):.4f}")
    print(f"Наивысшая точность достигнута на эпохе: {best_epoch}")

# %%
# DenseModel
def build_dense_model(input_shape=(28, 28), num_classes=10):
    # Создаем последовательную модель нейронной сети
    model = Sequential()
    # Входной полносвязный слой
    # - 800 нейронов: определяет количество нейронов в слое
    # - input_dim=784: указывает на количество входов в каждый нейрон, в данном случае, 784, так как входные данные представляют собой изображения размером 28x28 пикселей, которые были преобразованы в одномерный массив размером 784 пикселя
    # - activation="relu": функция активации ReLU (Rectified Linear Unit) применяется для добавления нелинейности в сеть
    model.add(Dense(800, input_dim=784, activation="relu"))
    # Выходной полносвязный слой
    # - 10 нейронов: количество нейронов в выходном слое соответствует количеству классов, в данном случае, 10 классов (цифры от 0 до 9)
    # - activation="softmax": функция активации Softmax применяется для преобразования выходов сети в вероятности принадлежности к каждому классу
    model.add(Dense(10, activation="softmax"))
    # Компиляция модели
    # - loss="categorical_crossentropy": функция потерь, используемая для оценки ошибки сети; в данном случае, используется категориальная перекрестная энтропия, так как у нас задача классификации с несколькими классами
    # - optimizer="SGD": оптимизатор, используемый для обучения сети; в данном случае, используется стохастический градиентный спуск (SGD)
    # - metrics=["accuracy"]: метрики, используемые для оценки производительности сети во время обучения; в данном случае, используется метрика точности (accuracy)
    model.compile(loss="categorical_crossentropy", optimizer="SGD", metrics=["accuracy"])

    return model

def train_dense_model(model, x_train, y_train, x_test, y_test, epochs=100, batch_size=64):
    train_model_base(model, x_train, y_train, x_test, y_test, epochs, batch_size)  # Вызываем метод из класса otherModel

def print_dense_metrics(model):
    print_metrics_base(model)   # Вызываем метод из класса otherModel

def transformation_img_dense(img_path):
    img = image.load_img(img_path, target_size=(28, 28), color_mode="grayscale")
    # Преобразуем картинку в массив
    x = image.img_to_array(img)
    x = x.reshape(1,784)
    # Нормализуем изображение
    x = 255 - x
    x /= 255
    # Выпрямляем изображение в одномерный массив
    x = x.flatten()
    # Добавляем размерность батча (1, 784)
    x = np.expand_dims(x, axis=0)
    return x

def predict_dense(model, img):
    print("Предсказанное число ", predict_dense_base(model, transformation_img_dense(img)))

# %%
# ConvModel:

def build_conv_model(input_shape=(28, 28, 1), num_classes=10):
    # Создаем последовательную модель нейронной сети
    model = Sequential()
    # Первый сверточный слой
    # 28 - количество фильтров, (3, 3) - размер ядра свертки, padding='same' - добавляет нулевые значения входам, чтобы размер выхода был таким же, как и у входа
    # input_shape=(28, 28, 1) - размерность входных данных (ширина, высота, количество каналов)
    # activation='relu' - функция активации ReLU (Rectified Linear Unit)
    model.add(Conv2D(28, (3, 3), padding='same', input_shape=(28, 28, 1), activation='relu'))
    # Второй сверточный слой
    # Аналогично первому слою, но без указания input_shape, так как это уже продолжение предыдущего слоя
    model.add(Conv2D(28, (3, 3), activation='relu', padding='same'))
    # Первый слой подвыборки
    # pool_size=(2, 2) - размер окна для уменьшения размерности
    model.add(MaxPooling2D(pool_size=(2, 2)))
    # Слой регуляризации Dropout
    # 0.25 - доля входных единиц, которые будут исключены случайным образом на каждом обновлении во время обучения для предотвращения переобучения
    model.add(Dropout(0.25))
    # Третий сверточный слой
    model.add(Conv2D(2 * 28, (3, 3), padding='same', activation='relu'))
    # Четвертый сверточный слой
    model.add(Conv2D(2 * 28, (3, 3), activation='relu'))
    # Второй слой подвыборки
    model.add(MaxPooling2D(pool_size=(2, 2)))
    # Слой регуляризации Dropout
    model.add(Dropout(0.25))
    # Слой преобразования данных из 2D представления в плоское
    model.add(Flatten())
    # Полносвязный слой для классификации
    # 8 * 28 - количество нейронов в слое
    model.add(Dense(8 * 28, activation='relu'))
    # Слой регуляризации Dropout
    model.add(Dropout(0.5))
    # Выходной полносвязный слой
    # 10 - количество классов для классификации
    model.add(Dense(10, activation='softmax'))
    # Компилируем модель
    # loss='categorical_crossentropy' - функция потерь для многоклассовой классификации
    # optimizer='adam' - оптимизатор Adam
    # metrics=['accuracy'] - метрика, используемая для оценки производительности модели
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

    return model

def transformation_img_conv(img_path):
    img = image.load_img(img_path, target_size=(28, 28), color_mode="grayscale")
    # Преобразуем картинку в массив
    x = image.img_to_array(img)
    x= 255 - x
    # Нормализуем изображение
    x /= 255
    # для второй нейронки
    x = np.expand_dims(x, axis=0)
    return x

#def train_conv_model(model, x_train, y_train, x_test, y_test, epochs=15, batch_size=64):
#    train_model_base(model, x_train, y_train, x_test, y_test, epochs, batch_size)  # Вызываем метод из класса otherModel

def predict_conv(model, img):
    print("Предсказанное число (Dense Model):", predict_dense_base(model, transformation_img_conv(img)))

# %%
# Загрузка данных MNIST
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Нормализация изображений
x_train = x_train / 255.0
x_test = x_test / 255.0

# %%
# Создание экземпляров классов моделей
#dense_model = DenseModel()

# %%
#conv_model = ConvModel()

# %%
# Обучение полносвязной нейронной сети
model = build_dense_model()

# Преобразовать форму входных данных
x_train_flat = x_train.reshape(x_train.shape[0], -1)
x_test_flat = x_test.reshape(x_test.shape[0], -1)

train_dense_model(model, x_train_flat, y_train, x_test_flat, y_test)
# Out:
# Epoch 1/100
# 750/750 - 7s - loss: 0.8800 - accuracy: 0.8061 - val_loss: 0.4604 - val_accuracy: 0.8886 - 7s/epoch - 10ms/step
# Epoch 2/100
# 750/750 - 5s - loss: 0.4290 - accuracy: 0.8885 - val_loss: 0.3563 - val_accuracy: 0.9053 - 5s/epoch - 7ms/step
# Epoch 3/100
# 750/750 - 7s - loss: 0.3591 - accuracy: 0.9019 - val_loss: 0.3168 - val_accuracy: 0.9145 - 7s/epoch - 9ms/step
# Epoch 4/100
# 750/750 - 6s - loss: 0.3238 - accuracy: 0.9096 - val_loss: 0.2932 - val_accuracy: 0.9191 - 6s/epoch - 8ms/step
# Epoch 5/100
# 750/750 - 7s - loss: 0.3003 - accuracy: 0.9168 - val_loss: 0.2757 - val_accuracy: 0.9242 - 7s/epoch - 9ms/step
# Epoch 6/100
# 750/750 - 5s - loss: 0.2818 - accuracy: 0.9217 - val_loss: 0.2615 - val_accuracy: 0.9273 - 5s/epoch - 7ms/step
# Epoch 7/100
# 750/750 - 6s - loss: 0.2666 - accuracy: 0.9263 - val_loss: 0.2494 - val_accuracy: 0.9333 - 6s/epoch - 8ms/step
# Epoch 8/100
# 750/750 - 6s - loss: 0.2533 - accuracy: 0.9302 - val_loss: 0.2385 - val_accuracy: 0.9342 - 6s/epoch - 8ms/step
# Epoch 9/100
# 750/750 - 6s - loss: 0.2417 - accuracy: 0.9329 - val_loss: 0.2298 - val_accuracy: 0.9366 - 6s/epoch - 8ms/step
# Epoch 10/100
# 750/750 - 5s - loss: 0.2312 - accuracy: 0.9361 - val_loss: 0.2210 - val_accuracy: 0.9409 - 5s/epoch - 7ms/step
# Epoch 11/100
# 750/750 - 6s - loss: 0.2217 - accuracy: 0.9386 - val_loss: 0.2137 - val_accuracy: 0.9422 - 6s/epoch - 8ms/step
# Epoch 12/100
# 750/750 - 6s - loss: 0.2129 - accuracy: 0.9412 - val_loss: 0.2064 - val_accuracy: 0.9438 - 6s/epoch - 8ms/step
# Epoch 13/100
# 750/750 - 5s - loss: 0.2047 - accuracy: 0.9438 - val_loss: 0.2003 - val_accuracy: 0.9460 - 5s/epoch - 7ms/step
# Epoch 14/100
# 750/750 - 6s - loss: 0.1973 - accuracy: 0.9456 - val_loss: 0.1933 - val_accuracy: 0.9482 - 6s/epoch - 7ms/step
# Epoch 15/100
# 750/750 - 6s - loss: 0.1903 - accuracy: 0.9474 - val_loss: 0.1883 - val_accuracy: 0.9490 - 6s/epoch - 8ms/step
# Epoch 16/100
# 750/750 - 7s - loss: 0.1839 - accuracy: 0.9495 - val_loss: 0.1833 - val_accuracy: 0.9509 - 7s/epoch - 9ms/step
# Epoch 17/100
# 750/750 - 5s - loss: 0.1775 - accuracy: 0.9506 - val_loss: 0.1789 - val_accuracy: 0.9518 - 5s/epoch - 7ms/step
# Epoch 18/100
# 750/750 - 6s - loss: 0.1719 - accuracy: 0.9523 - val_loss: 0.1734 - val_accuracy: 0.9532 - 6s/epoch - 8ms/step
# Epoch 19/100
# 750/750 - 5s - loss: 0.1664 - accuracy: 0.9539 - val_loss: 0.1702 - val_accuracy: 0.9534 - 5s/epoch - 7ms/step
# Epoch 20/100
# 750/750 - 6s - loss: 0.1615 - accuracy: 0.9550 - val_loss: 0.1654 - val_accuracy: 0.9560 - 6s/epoch - 8ms/step
# Epoch 21/100
# 750/750 - 6s - loss: 0.1567 - accuracy: 0.9564 - val_loss: 0.1618 - val_accuracy: 0.9561 - 6s/epoch - 7ms/step
# Epoch 22/100
# 750/750 - 6s - loss: 0.1523 - accuracy: 0.9579 - val_loss: 0.1584 - val_accuracy: 0.9582 - 6s/epoch - 8ms/step
# Epoch 23/100
# 750/750 - 5s - loss: 0.1481 - accuracy: 0.9591 - val_loss: 0.1550 - val_accuracy: 0.9581 - 5s/epoch - 7ms/step
# Epoch 24/100
# 750/750 - 6s - loss: 0.1439 - accuracy: 0.9602 - val_loss: 0.1519 - val_accuracy: 0.9593 - 6s/epoch - 8ms/step
# Epoch 25/100
# 750/750 - 6s - loss: 0.1401 - accuracy: 0.9613 - val_loss: 0.1496 - val_accuracy: 0.9603 - 6s/epoch - 8ms/step
# Epoch 26/100
# 750/750 - 6s - loss: 0.1364 - accuracy: 0.9624 - val_loss: 0.1464 - val_accuracy: 0.9603 - 6s/epoch - 8ms/step
# Epoch 27/100
# 750/750 - 5s - loss: 0.1331 - accuracy: 0.9637 - val_loss: 0.1441 - val_accuracy: 0.9617 - 5s/epoch - 7ms/step
# Epoch 28/100
# 750/750 - 6s - loss: 0.1298 - accuracy: 0.9645 - val_loss: 0.1410 - val_accuracy: 0.9618 - 6s/epoch - 8ms/step
# Epoch 29/100
# 750/750 - 7s - loss: 0.1265 - accuracy: 0.9661 - val_loss: 0.1388 - val_accuracy: 0.9621 - 7s/epoch - 9ms/step
# Epoch 30/100
# 750/750 - 6s - loss: 0.1235 - accuracy: 0.9671 - val_loss: 0.1369 - val_accuracy: 0.9627 - 6s/epoch - 8ms/step
# Epoch 31/100
# 750/750 - 6s - loss: 0.1207 - accuracy: 0.9680 - val_loss: 0.1346 - val_accuracy: 0.9626 - 6s/epoch - 8ms/step
# Epoch 32/100
# 750/750 - 5s - loss: 0.1179 - accuracy: 0.9684 - val_loss: 0.1330 - val_accuracy: 0.9639 - 5s/epoch - 7ms/step
# Epoch 33/100
# 750/750 - 6s - loss: 0.1153 - accuracy: 0.9692 - val_loss: 0.1309 - val_accuracy: 0.9631 - 6s/epoch - 8ms/step
# Epoch 34/100
# 750/750 - 6s - loss: 0.1128 - accuracy: 0.9697 - val_loss: 0.1296 - val_accuracy: 0.9643 - 6s/epoch - 8ms/step
# Epoch 35/100
# 750/750 - 6s - loss: 0.1103 - accuracy: 0.9710 - val_loss: 0.1273 - val_accuracy: 0.9653 - 6s/epoch - 8ms/step
# Epoch 36/100
# 750/750 - 6s - loss: 0.1079 - accuracy: 0.9713 - val_loss: 0.1254 - val_accuracy: 0.9649 - 6s/epoch - 8ms/step
# Epoch 37/100
# 750/750 - 7s - loss: 0.1056 - accuracy: 0.9718 - val_loss: 0.1246 - val_accuracy: 0.9658 - 7s/epoch - 9ms/step
# Epoch 38/100
# 750/750 - 6s - loss: 0.1037 - accuracy: 0.9720 - val_loss: 0.1226 - val_accuracy: 0.9657 - 6s/epoch - 8ms/step
# Epoch 39/100
# 750/750 - 6s - loss: 0.1015 - accuracy: 0.9729 - val_loss: 0.1218 - val_accuracy: 0.9663 - 6s/epoch - 9ms/step
# Epoch 40/100
# 750/750 - 5s - loss: 0.0995 - accuracy: 0.9734 - val_loss: 0.1201 - val_accuracy: 0.9678 - 5s/epoch - 7ms/step
# Epoch 41/100
# 750/750 - 6s - loss: 0.0976 - accuracy: 0.9740 - val_loss: 0.1184 - val_accuracy: 0.9681 - 6s/epoch - 8ms/step
# Epoch 42/100
# 750/750 - 5s - loss: 0.0956 - accuracy: 0.9749 - val_loss: 0.1177 - val_accuracy: 0.9669 - 5s/epoch - 7ms/step
# Epoch 43/100
# 750/750 - 6s - loss: 0.0938 - accuracy: 0.9751 - val_loss: 0.1162 - val_accuracy: 0.9684 - 6s/epoch - 8ms/step
# Epoch 44/100
# 750/750 - 6s - loss: 0.0920 - accuracy: 0.9756 - val_loss: 0.1148 - val_accuracy: 0.9693 - 6s/epoch - 8ms/step
# Epoch 45/100
# 750/750 - 6s - loss: 0.0904 - accuracy: 0.9761 - val_loss: 0.1138 - val_accuracy: 0.9687 - 6s/epoch - 8ms/step
# Epoch 46/100
# 750/750 - 6s - loss: 0.0887 - accuracy: 0.9771 - val_loss: 0.1122 - val_accuracy: 0.9692 - 6s/epoch - 8ms/step
# Epoch 47/100
# 750/750 - 6s - loss: 0.0871 - accuracy: 0.9769 - val_loss: 0.1113 - val_accuracy: 0.9693 - 6s/epoch - 8ms/step
# Epoch 48/100
# 750/750 - 6s - loss: 0.0856 - accuracy: 0.9776 - val_loss: 0.1102 - val_accuracy: 0.9696 - 6s/epoch - 9ms/step
# Epoch 49/100
# 750/750 - 6s - loss: 0.0840 - accuracy: 0.9781 - val_loss: 0.1095 - val_accuracy: 0.9696 - 6s/epoch - 8ms/step
# Epoch 50/100
# 750/750 - 6s - loss: 0.0826 - accuracy: 0.9784 - val_loss: 0.1085 - val_accuracy: 0.9697 - 6s/epoch - 7ms/step
# Epoch 51/100
# 750/750 - 6s - loss: 0.0812 - accuracy: 0.9786 - val_loss: 0.1072 - val_accuracy: 0.9703 - 6s/epoch - 8ms/step
# Epoch 52/100
# 750/750 - 6s - loss: 0.0798 - accuracy: 0.9795 - val_loss: 0.1067 - val_accuracy: 0.9698 - 6s/epoch - 8ms/step
# Epoch 53/100
# 750/750 - 6s - loss: 0.0785 - accuracy: 0.9797 - val_loss: 0.1058 - val_accuracy: 0.9703 - 6s/epoch - 8ms/step
# Epoch 54/100
# 750/750 - 6s - loss: 0.0772 - accuracy: 0.9801 - val_loss: 0.1045 - val_accuracy: 0.9709 - 6s/epoch - 8ms/step
# Epoch 55/100
# 750/750 - 5s - loss: 0.0759 - accuracy: 0.9807 - val_loss: 0.1038 - val_accuracy: 0.9703 - 5s/epoch - 7ms/step
# Epoch 56/100
# 750/750 - 7s - loss: 0.0747 - accuracy: 0.9804 - val_loss: 0.1031 - val_accuracy: 0.9704 - 7s/epoch - 9ms/step
# Epoch 57/100
# 750/750 - 6s - loss: 0.0734 - accuracy: 0.9812 - val_loss: 0.1025 - val_accuracy: 0.9708 - 6s/epoch - 8ms/step
# Epoch 58/100
# 750/750 - 6s - loss: 0.0723 - accuracy: 0.9817 - val_loss: 0.1015 - val_accuracy: 0.9712 - 6s/epoch - 8ms/step
# Epoch 59/100
# 750/750 - 6s - loss: 0.0711 - accuracy: 0.9821 - val_loss: 0.1004 - val_accuracy: 0.9717 - 6s/epoch - 8ms/step
# Epoch 60/100
# 750/750 - 7s - loss: 0.0700 - accuracy: 0.9823 - val_loss: 0.1006 - val_accuracy: 0.9713 - 7s/epoch - 9ms/step
# Epoch 61/100
# 750/750 - 5s - loss: 0.0689 - accuracy: 0.9826 - val_loss: 0.0996 - val_accuracy: 0.9712 - 5s/epoch - 7ms/step
# Epoch 62/100
# 750/750 - 6s - loss: 0.0679 - accuracy: 0.9830 - val_loss: 0.0987 - val_accuracy: 0.9723 - 6s/epoch - 8ms/step
# Epoch 63/100
# 750/750 - 5s - loss: 0.0669 - accuracy: 0.9835 - val_loss: 0.0986 - val_accuracy: 0.9720 - 5s/epoch - 7ms/step
# Epoch 64/100
# 750/750 - 6s - loss: 0.0657 - accuracy: 0.9836 - val_loss: 0.0976 - val_accuracy: 0.9719 - 6s/epoch - 8ms/step
# Epoch 65/100
# 750/750 - 5s - loss: 0.0649 - accuracy: 0.9836 - val_loss: 0.0967 - val_accuracy: 0.9730 - 5s/epoch - 7ms/step
# Epoch 66/100
# 750/750 - 5s - loss: 0.0639 - accuracy: 0.9839 - val_loss: 0.0962 - val_accuracy: 0.9729 - 5s/epoch - 7ms/step
# Epoch 67/100
# 750/750 - 6s - loss: 0.0629 - accuracy: 0.9844 - val_loss: 0.0959 - val_accuracy: 0.9722 - 6s/epoch - 8ms/step
# Epoch 68/100
# 750/750 - 5s - loss: 0.0620 - accuracy: 0.9845 - val_loss: 0.0957 - val_accuracy: 0.9723 - 5s/epoch - 7ms/step
# Epoch 69/100
# 750/750 - 6s - loss: 0.0612 - accuracy: 0.9847 - val_loss: 0.0948 - val_accuracy: 0.9734 - 6s/epoch - 9ms/step
# Epoch 70/100
# 750/750 - 5s - loss: 0.0603 - accuracy: 0.9849 - val_loss: 0.0942 - val_accuracy: 0.9730 - 5s/epoch - 7ms/step
# Epoch 71/100
# 750/750 - 6s - loss: 0.0594 - accuracy: 0.9854 - val_loss: 0.0936 - val_accuracy: 0.9732 - 6s/epoch - 8ms/step
# Epoch 72/100
# 750/750 - 6s - loss: 0.0586 - accuracy: 0.9855 - val_loss: 0.0937 - val_accuracy: 0.9729 - 6s/epoch - 8ms/step
# Epoch 73/100
# 750/750 - 7s - loss: 0.0579 - accuracy: 0.9856 - val_loss: 0.0926 - val_accuracy: 0.9731 - 7s/epoch - 9ms/step
# Epoch 74/100
# 750/750 - 6s - loss: 0.0570 - accuracy: 0.9858 - val_loss: 0.0924 - val_accuracy: 0.9733 - 6s/epoch - 7ms/step
# Epoch 75/100
# 750/750 - 6s - loss: 0.0562 - accuracy: 0.9861 - val_loss: 0.0918 - val_accuracy: 0.9731 - 6s/epoch - 8ms/step
# Epoch 76/100
# 750/750 - 5s - loss: 0.0555 - accuracy: 0.9864 - val_loss: 0.0916 - val_accuracy: 0.9735 - 5s/epoch - 7ms/step
# Epoch 77/100
# 750/750 - 6s - loss: 0.0547 - accuracy: 0.9865 - val_loss: 0.0911 - val_accuracy: 0.9738 - 6s/epoch - 8ms/step
# Epoch 78/100
# 750/750 - 5s - loss: 0.0540 - accuracy: 0.9868 - val_loss: 0.0906 - val_accuracy: 0.9732 - 5s/epoch - 7ms/step
# Epoch 79/100
# 750/750 - 6s - loss: 0.0533 - accuracy: 0.9867 - val_loss: 0.0904 - val_accuracy: 0.9739 - 6s/epoch - 8ms/step
# Epoch 80/100
# 750/750 - 6s - loss: 0.0526 - accuracy: 0.9874 - val_loss: 0.0896 - val_accuracy: 0.9739 - 6s/epoch - 8ms/step
# Epoch 81/100
# 750/750 - 6s - loss: 0.0519 - accuracy: 0.9874 - val_loss: 0.0890 - val_accuracy: 0.9740 - 6s/epoch - 8ms/step
# Epoch 82/100
# 750/750 - 6s - loss: 0.0512 - accuracy: 0.9878 - val_loss: 0.0891 - val_accuracy: 0.9732 - 6s/epoch - 8ms/step
# Epoch 83/100
# 750/750 - 5s - loss: 0.0506 - accuracy: 0.9878 - val_loss: 0.0887 - val_accuracy: 0.9737 - 5s/epoch - 7ms/step
# Epoch 84/100
# 750/750 - 7s - loss: 0.0498 - accuracy: 0.9880 - val_loss: 0.0882 - val_accuracy: 0.9741 - 7s/epoch - 9ms/step
# Epoch 85/100
# 750/750 - 6s - loss: 0.0492 - accuracy: 0.9882 - val_loss: 0.0876 - val_accuracy: 0.9739 - 6s/epoch - 8ms/step
# Epoch 86/100
# 750/750 - 6s - loss: 0.0486 - accuracy: 0.9884 - val_loss: 0.0873 - val_accuracy: 0.9740 - 6s/epoch - 8ms/step
# Epoch 87/100
# 750/750 - 6s - loss: 0.0480 - accuracy: 0.9885 - val_loss: 0.0878 - val_accuracy: 0.9730 - 6s/epoch - 8ms/step
# Epoch 88/100
# 750/750 - 7s - loss: 0.0474 - accuracy: 0.9888 - val_loss: 0.0867 - val_accuracy: 0.9738 - 7s/epoch - 9ms/step
# Epoch 89/100
# 750/750 - 5s - loss: 0.0468 - accuracy: 0.9889 - val_loss: 0.0866 - val_accuracy: 0.9744 - 5s/epoch - 7ms/step
# Epoch 90/100
# 750/750 - 6s - loss: 0.0462 - accuracy: 0.9890 - val_loss: 0.0863 - val_accuracy: 0.9739 - 6s/epoch - 9ms/step
# Epoch 91/100
# 750/750 - 6s - loss: 0.0457 - accuracy: 0.9891 - val_loss: 0.0862 - val_accuracy: 0.9749 - 6s/epoch - 7ms/step
# Epoch 92/100
# 750/750 - 6s - loss: 0.0451 - accuracy: 0.9894 - val_loss: 0.0856 - val_accuracy: 0.9747 - 6s/epoch - 8ms/step
# Epoch 93/100
# 750/750 - 5s - loss: 0.0446 - accuracy: 0.9895 - val_loss: 0.0856 - val_accuracy: 0.9744 - 5s/epoch - 7ms/step
# Epoch 94/100
# 750/750 - 6s - loss: 0.0440 - accuracy: 0.9898 - val_loss: 0.0853 - val_accuracy: 0.9744 - 6s/epoch - 8ms/step
# Epoch 95/100
# 750/750 - 5s - loss: 0.0435 - accuracy: 0.9900 - val_loss: 0.0849 - val_accuracy: 0.9750 - 5s/epoch - 7ms/step
# Epoch 96/100
# 750/750 - 6s - loss: 0.0430 - accuracy: 0.9901 - val_loss: 0.0848 - val_accuracy: 0.9747 - 6s/epoch - 8ms/step
# Epoch 97/100
# 750/750 - 5s - loss: 0.0424 - accuracy: 0.9905 - val_loss: 0.0846 - val_accuracy: 0.9749 - 5s/epoch - 7ms/step
# Epoch 98/100
# 750/750 - 6s - loss: 0.0419 - accuracy: 0.9904 - val_loss: 0.0838 - val_accuracy: 0.9755 - 6s/epoch - 8ms/step
# Epoch 99/100
# 750/750 - 6s - loss: 0.0414 - accuracy: 0.9906 - val_loss: 0.0838 - val_accuracy: 0.9753 - 6s/epoch - 7ms/step
# Epoch 100/100
# 750/750 - 5s - loss: 0.0410 - accuracy: 0.9910 - val_loss: 0.0836 - val_accuracy: 0.9760 - 5s/epoch - 7ms/step

# %%
print_metrics_base(model)
# Out:
# Метрики обучения:
# ---------------------------------------------------------
# Максимальная точность на тренировочном наборе: 0.9910
# Минимальная потеря на тренировочном наборе: 0.0410
# Максимальная точность на валидационном наборе: 0.9760
# Минимальная потеря на валидационном наборе: 0.0836
# Наивысшая точность достигнута на эпохе: 100

# %%
def dense(model, path):
    predict_dense(model, path)

# %%
import os

# Укажите путь к папке, которую вы хотите просканировать
folder_path = '/content/'

# Допустимые расширения файлов изображений
image_extensions = ['.jpg', '.jpeg', '.png']

# Цикл для перебора всех файлов в папке
for root, dirs, files in os.walk(folder_path):
    for file_name in files:
        # Полный путь к файлу
        file_path = os.path.join(root, file_name)

        # Получение расширения файла
        file_extension = os.path.splitext(file_name)[1].lower()

        # Проверка, является ли файл изображением
        if file_extension in image_extensions:
            print(f"-------{file_path}---------")
            dense(model, file_path)
# Out:
# -------/content/num5_1.png---------
# shape: (1, 784)
# 1/1 [==============================] - 0s 59ms/step
# Предсказанное число  5
# -------/content/num0_1.png---------
# shape: (1, 784)
# 1/1 [==============================] - 0s 26ms/step
# Предсказанное число  0
# -------/content/num4.png---------
# shape: (1, 784)
# 1/1 [==============================] - 0s 26ms/step
# Предсказанное число  4
# -------/content/num7_3.png---------
# shape: (1, 784)
# 1/1 [==============================] - 0s 23ms/step
# Предсказанное число  6
# -------/content/num1_1.png---------
# shape: (1, 784)
# 1/1 [==============================] - 0s 24ms/step
# Предсказанное число  1
# -------/content/num5_3.png---------
# shape: (1, 784)
# 1/1 [==============================] - 0s 34ms/step
# Предсказанное число  5
# -------/content/num8_1.png---------
# shape: (1, 784)
# 1/1 [==============================] - 0s 34ms/step
# Предсказанное число  2
# -------/content/num6_1.png---------
# shape: (1, 784)
# 1/1 [==============================] - 0s 31ms/step
# Предсказанное число  8
# -------/content/num3_1.png---------
# shape: (1, 784)
# 1/1 [==============================] - 0s 47ms/step
# Предсказанное число  3
# -------/content/num9_1.png---------
# shape: (1, 784)
# 1/1 [==============================] - 0s 34ms/step
# Предсказанное число  8
# -------/content/num7_2.png---------
# shape: (1, 784)
# 1/1 [==============================] - 0s 36ms/step
# Предсказанное число  3
# -------/content/num2_1.png---------
# shape: (1, 784)
# 1/1 [==============================] - 0s 40ms/step
# Предсказанное число  2
# -------/content/num5_2.png---------
# shape: (1, 784)
# 1/1 [==============================] - 0s 31ms/step
# Предсказанное число  5
# -------/content/num6_2.png---------
# shape: (1, 784)
# 1/1 [==============================] - 0s 30ms/step
# Предсказанное число  5
# -------/content/num7_1.png---------
# shape: (1, 784)
# 1/1 [==============================] - 0s 33ms/step
# Предсказанное число  3

# %%
# Изменение формы входных данных для сверточной сети
x_train_conv = x_train.reshape(-1, 28, 28, 1)
x_test_conv = x_test.reshape(-1, 28, 28, 1)

# Обучение сверточной нейронной сети
model_conv = build_conv_model()

# %%
train_model_base(model_conv, x_train_conv, y_train, x_test_conv, y_test)
# Out:
# Epoch 1/100
# 240/240 - 151s - loss: 0.3525 - accuracy: 0.8845 - val_loss: 0.0607 - val_accuracy: 0.9817 - 151s/epoch - 630ms/step
# Epoch 2/100
# 240/240 - 144s - loss: 0.0943 - accuracy: 0.9717 - val_loss: 0.0512 - val_accuracy: 0.9856 - 144s/epoch - 601ms/step
# Epoch 3/100
# 240/240 - 152s - loss: 0.0676 - accuracy: 0.9792 - val_loss: 0.0396 - val_accuracy: 0.9885 - 152s/epoch - 634ms/step
# Epoch 4/100
# 240/240 - 144s - loss: 0.0569 - accuracy: 0.9830 - val_loss: 0.0315 - val_accuracy: 0.9912 - 144s/epoch - 598ms/step
# Epoch 5/100
# 240/240 - 142s - loss: 0.0495 - accuracy: 0.9848 - val_loss: 0.0298 - val_accuracy: 0.9917 - 142s/epoch - 590ms/step
# Epoch 6/100
# 240/240 - 140s - loss: 0.0395 - accuracy: 0.9874 - val_loss: 0.0317 - val_accuracy: 0.9918 - 140s/epoch - 583ms/step
# Epoch 7/100
# 240/240 - 140s - loss: 0.0385 - accuracy: 0.9883 - val_loss: 0.0329 - val_accuracy: 0.9913 - 140s/epoch - 584ms/step
# Epoch 8/100
# 240/240 - 148s - loss: 0.0326 - accuracy: 0.9895 - val_loss: 0.0280 - val_accuracy: 0.9923 - 148s/epoch - 615ms/step
# Epoch 9/100
# 240/240 - 150s - loss: 0.0307 - accuracy: 0.9907 - val_loss: 0.0264 - val_accuracy: 0.9927 - 150s/epoch - 627ms/step
# Epoch 10/100
# 240/240 - 151s - loss: 0.0268 - accuracy: 0.9915 - val_loss: 0.0251 - val_accuracy: 0.9934 - 151s/epoch - 630ms/step
# Epoch 11/100
# 240/240 - 152s - loss: 0.0246 - accuracy: 0.9916 - val_loss: 0.0317 - val_accuracy: 0.9928 - 152s/epoch - 635ms/step
# Epoch 12/100
# 240/240 - 143s - loss: 0.0261 - accuracy: 0.9915 - val_loss: 0.0253 - val_accuracy: 0.9929 - 143s/epoch - 595ms/step
# Epoch 13/100
# 240/240 - 140s - loss: 0.0220 - accuracy: 0.9927 - val_loss: 0.0303 - val_accuracy: 0.9927 - 140s/epoch - 584ms/step
# Epoch 14/100
# 240/240 - 141s - loss: 0.0202 - accuracy: 0.9936 - val_loss: 0.0280 - val_accuracy: 0.9933 - 141s/epoch - 589ms/step
# Epoch 15/100
# 240/240 - 141s - loss: 0.0196 - accuracy: 0.9935 - val_loss: 0.0287 - val_accuracy: 0.9927 - 141s/epoch - 588ms/step
# Epoch 16/100
# 240/240 - 141s - loss: 0.0180 - accuracy: 0.9941 - val_loss: 0.0265 - val_accuracy: 0.9930 - 141s/epoch - 587ms/step
# Epoch 17/100
# 240/240 - 141s - loss: 0.0172 - accuracy: 0.9939 - val_loss: 0.0299 - val_accuracy: 0.9933 - 141s/epoch - 586ms/step
# Epoch 18/100
# 240/240 - 136s - loss: 0.0180 - accuracy: 0.9944 - val_loss: 0.0304 - val_accuracy: 0.9933 - 136s/epoch - 568ms/step
# Epoch 19/100
# 240/240 - 143s - loss: 0.0169 - accuracy: 0.9946 - val_loss: 0.0274 - val_accuracy: 0.9933 - 143s/epoch - 594ms/step
# Epoch 20/100
# 240/240 - 137s - loss: 0.0158 - accuracy: 0.9948 - val_loss: 0.0271 - val_accuracy: 0.9937 - 137s/epoch - 572ms/step
# Epoch 21/100
# 240/240 - 141s - loss: 0.0136 - accuracy: 0.9953 - val_loss: 0.0308 - val_accuracy: 0.9937 - 141s/epoch - 588ms/step
# Epoch 22/100
# 240/240 - 140s - loss: 0.0141 - accuracy: 0.9951 - val_loss: 0.0274 - val_accuracy: 0.9942 - 140s/epoch - 584ms/step
# Epoch 23/100
# 240/240 - 141s - loss: 0.0139 - accuracy: 0.9956 - val_loss: 0.0303 - val_accuracy: 0.9933 - 141s/epoch - 586ms/step
# Epoch 24/100
# 240/240 - 143s - loss: 0.0125 - accuracy: 0.9960 - val_loss: 0.0258 - val_accuracy: 0.9938 - 143s/epoch - 595ms/step
# Epoch 25/100
# 240/240 - 141s - loss: 0.0124 - accuracy: 0.9958 - val_loss: 0.0270 - val_accuracy: 0.9937 - 141s/epoch - 590ms/step
# Epoch 26/100
# 240/240 - 142s - loss: 0.0123 - accuracy: 0.9959 - val_loss: 0.0297 - val_accuracy: 0.9941 - 142s/epoch - 592ms/step
# Epoch 27/100
# 240/240 - 142s - loss: 0.0126 - accuracy: 0.9957 - val_loss: 0.0275 - val_accuracy: 0.9942 - 142s/epoch - 592ms/step
# Epoch 28/100
# 240/240 - 140s - loss: 0.0122 - accuracy: 0.9958 - val_loss: 0.0269 - val_accuracy: 0.9935 - 140s/epoch - 585ms/step
# Epoch 29/100
# 240/240 - 142s - loss: 0.0132 - accuracy: 0.9955 - val_loss: 0.0298 - val_accuracy: 0.9941 - 142s/epoch - 593ms/step
# Epoch 30/100
# 240/240 - 141s - loss: 0.0121 - accuracy: 0.9961 - val_loss: 0.0284 - val_accuracy: 0.9944 - 141s/epoch - 586ms/step
# Epoch 31/100
# 240/240 - 144s - loss: 0.0105 - accuracy: 0.9965 - val_loss: 0.0314 - val_accuracy: 0.9942 - 144s/epoch - 598ms/step
# Epoch 32/100
# 240/240 - 144s - loss: 0.0106 - accuracy: 0.9964 - val_loss: 0.0311 - val_accuracy: 0.9942 - 144s/epoch - 598ms/step
# Epoch 33/100
# 240/240 - 143s - loss: 0.0085 - accuracy: 0.9971 - val_loss: 0.0294 - val_accuracy: 0.9947 - 143s/epoch - 596ms/step
# Epoch 34/100
# 240/240 - 142s - loss: 0.0102 - accuracy: 0.9966 - val_loss: 0.0412 - val_accuracy: 0.9923 - 142s/epoch - 590ms/step
# Epoch 35/100
# 240/240 - 143s - loss: 0.0113 - accuracy: 0.9966 - val_loss: 0.0270 - val_accuracy: 0.9950 - 143s/epoch - 595ms/step
# Epoch 36/100
# 240/240 - 141s - loss: 0.0099 - accuracy: 0.9970 - val_loss: 0.0277 - val_accuracy: 0.9944 - 141s/epoch - 586ms/step
# Epoch 37/100
# 240/240 - 140s - loss: 0.0101 - accuracy: 0.9968 - val_loss: 0.0285 - val_accuracy: 0.9948 - 140s/epoch - 585ms/step
# Epoch 38/100
# 240/240 - 140s - loss: 0.0092 - accuracy: 0.9971 - val_loss: 0.0244 - val_accuracy: 0.9952 - 140s/epoch - 585ms/step
# Epoch 39/100
# 240/240 - 143s - loss: 0.0094 - accuracy: 0.9970 - val_loss: 0.0306 - val_accuracy: 0.9945 - 143s/epoch - 595ms/step
# Epoch 40/100
# 240/240 - 139s - loss: 0.0082 - accuracy: 0.9972 - val_loss: 0.0317 - val_accuracy: 0.9948 - 139s/epoch - 580ms/step
# Epoch 41/100
# 240/240 - 143s - loss: 0.0107 - accuracy: 0.9968 - val_loss: 0.0292 - val_accuracy: 0.9940 - 143s/epoch - 594ms/step
# Epoch 42/100
# 240/240 - 143s - loss: 0.0089 - accuracy: 0.9969 - val_loss: 0.0300 - val_accuracy: 0.9945 - 143s/epoch - 594ms/step
# Epoch 43/100
# 240/240 - 143s - loss: 0.0081 - accuracy: 0.9974 - val_loss: 0.0313 - val_accuracy: 0.9943 - 143s/epoch - 595ms/step
# Epoch 44/100
# 240/240 - 144s - loss: 0.0074 - accuracy: 0.9976 - val_loss: 0.0324 - val_accuracy: 0.9940 - 144s/epoch - 598ms/step
# Epoch 45/100
# 240/240 - 142s - loss: 0.0083 - accuracy: 0.9975 - val_loss: 0.0266 - val_accuracy: 0.9948 - 142s/epoch - 592ms/step
# Epoch 46/100
# 240/240 - 144s - loss: 0.0071 - accuracy: 0.9978 - val_loss: 0.0274 - val_accuracy: 0.9942 - 144s/epoch - 599ms/step
# Epoch 47/100
# 240/240 - 144s - loss: 0.0068 - accuracy: 0.9979 - val_loss: 0.0316 - val_accuracy: 0.9942 - 144s/epoch - 598ms/step
# Epoch 48/100
# 240/240 - 141s - loss: 0.0084 - accuracy: 0.9971 - val_loss: 0.0304 - val_accuracy: 0.9941 - 141s/epoch - 586ms/step
# Epoch 49/100
# 240/240 - 140s - loss: 0.0076 - accuracy: 0.9975 - val_loss: 0.0343 - val_accuracy: 0.9935 - 140s/epoch - 581ms/step
# Epoch 50/100
# 240/240 - 137s - loss: 0.0075 - accuracy: 0.9975 - val_loss: 0.0331 - val_accuracy: 0.9944 - 137s/epoch - 571ms/step
# Epoch 51/100
# 240/240 - 142s - loss: 0.0076 - accuracy: 0.9977 - val_loss: 0.0337 - val_accuracy: 0.9946 - 142s/epoch - 591ms/step
# Epoch 52/100
# 240/240 - 142s - loss: 0.0063 - accuracy: 0.9980 - val_loss: 0.0274 - val_accuracy: 0.9946 - 142s/epoch - 591ms/step
# Epoch 53/100
# 240/240 - 143s - loss: 0.0078 - accuracy: 0.9976 - val_loss: 0.0311 - val_accuracy: 0.9938 - 143s/epoch - 597ms/step
# Epoch 54/100
# 240/240 - 143s - loss: 0.0067 - accuracy: 0.9976 - val_loss: 0.0294 - val_accuracy: 0.9949 - 143s/epoch - 597ms/step
# Epoch 55/100
# 240/240 - 142s - loss: 0.0056 - accuracy: 0.9983 - val_loss: 0.0338 - val_accuracy: 0.9942 - 142s/epoch - 594ms/step
# Epoch 56/100
# 240/240 - 141s - loss: 0.0061 - accuracy: 0.9978 - val_loss: 0.0315 - val_accuracy: 0.9949 - 141s/epoch - 588ms/step
# Epoch 57/100
# 240/240 - 143s - loss: 0.0082 - accuracy: 0.9975 - val_loss: 0.0370 - val_accuracy: 0.9940 - 143s/epoch - 596ms/step
# Epoch 58/100
# 240/240 - 140s - loss: 0.0053 - accuracy: 0.9982 - val_loss: 0.0360 - val_accuracy: 0.9942 - 140s/epoch - 583ms/step
# Epoch 59/100
# 240/240 - 140s - loss: 0.0070 - accuracy: 0.9975 - val_loss: 0.0339 - val_accuracy: 0.9946 - 140s/epoch - 584ms/step
# Epoch 60/100
# 240/240 - 142s - loss: 0.0061 - accuracy: 0.9982 - val_loss: 0.0302 - val_accuracy: 0.9952 - 142s/epoch - 593ms/step
# Epoch 61/100
# 240/240 - 143s - loss: 0.0062 - accuracy: 0.9980 - val_loss: 0.0418 - val_accuracy: 0.9936 - 143s/epoch - 596ms/step
# Epoch 62/100
# 240/240 - 143s - loss: 0.0091 - accuracy: 0.9971 - val_loss: 0.0298 - val_accuracy: 0.9951 - 143s/epoch - 596ms/step
# Epoch 63/100
# 240/240 - 139s - loss: 0.0048 - accuracy: 0.9983 - val_loss: 0.0377 - val_accuracy: 0.9941 - 139s/epoch - 580ms/step
# Epoch 64/100
# 240/240 - 142s - loss: 0.0072 - accuracy: 0.9978 - val_loss: 0.0332 - val_accuracy: 0.9942 - 142s/epoch - 590ms/step
# Epoch 65/100
# 240/240 - 141s - loss: 0.0045 - accuracy: 0.9985 - val_loss: 0.0359 - val_accuracy: 0.9945 - 141s/epoch - 588ms/step
# Epoch 66/100
# 240/240 - 141s - loss: 0.0063 - accuracy: 0.9980 - val_loss: 0.0366 - val_accuracy: 0.9939 - 141s/epoch - 586ms/step
# Epoch 67/100
# 240/240 - 144s - loss: 0.0073 - accuracy: 0.9978 - val_loss: 0.0288 - val_accuracy: 0.9954 - 144s/epoch - 600ms/step
# Epoch 68/100
# 240/240 - 142s - loss: 0.0051 - accuracy: 0.9984 - val_loss: 0.0331 - val_accuracy: 0.9943 - 142s/epoch - 590ms/step
# Epoch 69/100
# 240/240 - 143s - loss: 0.0056 - accuracy: 0.9983 - val_loss: 0.0359 - val_accuracy: 0.9943 - 143s/epoch - 596ms/step
# Epoch 70/100
# 240/240 - 144s - loss: 0.0066 - accuracy: 0.9981 - val_loss: 0.0287 - val_accuracy: 0.9944 - 144s/epoch - 598ms/step
# Epoch 71/100
# 240/240 - 140s - loss: 0.0053 - accuracy: 0.9983 - val_loss: 0.0335 - val_accuracy: 0.9948 - 140s/epoch - 582ms/step
# Epoch 72/100
# 240/240 - 139s - loss: 0.0047 - accuracy: 0.9985 - val_loss: 0.0336 - val_accuracy: 0.9948 - 139s/epoch - 578ms/step
# Epoch 73/100
# 240/240 - 139s - loss: 0.0057 - accuracy: 0.9981 - val_loss: 0.0390 - val_accuracy: 0.9940 - 139s/epoch - 578ms/step
# Epoch 74/100
# 240/240 - 141s - loss: 0.0061 - accuracy: 0.9981 - val_loss: 0.0370 - val_accuracy: 0.9945 - 141s/epoch - 587ms/step
# Epoch 75/100
# 240/240 - 139s - loss: 0.0053 - accuracy: 0.9983 - val_loss: 0.0338 - val_accuracy: 0.9947 - 139s/epoch - 580ms/step
# Epoch 76/100
# 240/240 - 137s - loss: 0.0051 - accuracy: 0.9983 - val_loss: 0.0340 - val_accuracy: 0.9950 - 137s/epoch - 572ms/step
# Epoch 77/100
# 240/240 - 143s - loss: 0.0054 - accuracy: 0.9981 - val_loss: 0.0309 - val_accuracy: 0.9951 - 143s/epoch - 594ms/step
# Epoch 78/100
# 240/240 - 142s - loss: 0.0061 - accuracy: 0.9981 - val_loss: 0.0316 - val_accuracy: 0.9952 - 142s/epoch - 590ms/step
# Epoch 79/100
# 240/240 - 141s - loss: 0.0060 - accuracy: 0.9981 - val_loss: 0.0304 - val_accuracy: 0.9951 - 141s/epoch - 588ms/step
# Epoch 80/100
# 240/240 - 143s - loss: 0.0062 - accuracy: 0.9980 - val_loss: 0.0342 - val_accuracy: 0.9950 - 143s/epoch - 594ms/step
# Epoch 81/100
# 240/240 - 141s - loss: 0.0051 - accuracy: 0.9983 - val_loss: 0.0321 - val_accuracy: 0.9951 - 141s/epoch - 588ms/step
# Epoch 82/100
# 240/240 - 142s - loss: 0.0043 - accuracy: 0.9985 - val_loss: 0.0347 - val_accuracy: 0.9945 - 142s/epoch - 592ms/step
# Epoch 83/100
# 240/240 - 143s - loss: 0.0051 - accuracy: 0.9984 - val_loss: 0.0327 - val_accuracy: 0.9942 - 143s/epoch - 595ms/step
# Epoch 84/100
# 240/240 - 141s - loss: 0.0046 - accuracy: 0.9984 - val_loss: 0.0359 - val_accuracy: 0.9948 - 141s/epoch - 587ms/step
# Epoch 85/100
# 240/240 - 143s - loss: 0.0048 - accuracy: 0.9984 - val_loss: 0.0368 - val_accuracy: 0.9945 - 143s/epoch - 594ms/step
# Epoch 86/100
# 240/240 - 141s - loss: 0.0053 - accuracy: 0.9981 - val_loss: 0.0345 - val_accuracy: 0.9948 - 141s/epoch - 587ms/step
# Epoch 87/100
# 240/240 - 141s - loss: 0.0054 - accuracy: 0.9981 - val_loss: 0.0346 - val_accuracy: 0.9953 - 141s/epoch - 589ms/step
# Epoch 88/100
# 240/240 - 143s - loss: 0.0041 - accuracy: 0.9986 - val_loss: 0.0375 - val_accuracy: 0.9956 - 143s/epoch - 595ms/step
# Epoch 89/100
# 240/240 - 134s - loss: 0.0037 - accuracy: 0.9986 - val_loss: 0.0373 - val_accuracy: 0.9949 - 134s/epoch - 560ms/step
# Epoch 90/100
# 240/240 - 143s - loss: 0.0057 - accuracy: 0.9983 - val_loss: 0.0367 - val_accuracy: 0.9947 - 143s/epoch - 596ms/step
# Epoch 91/100
# 240/240 - 141s - loss: 0.0049 - accuracy: 0.9981 - val_loss: 0.0362 - val_accuracy: 0.9944 - 141s/epoch - 587ms/step
# Epoch 92/100
# 240/240 - 143s - loss: 0.0063 - accuracy: 0.9983 - val_loss: 0.0367 - val_accuracy: 0.9937 - 143s/epoch - 594ms/step
# Epoch 93/100
# 240/240 - 140s - loss: 0.0044 - accuracy: 0.9985 - val_loss: 0.0387 - val_accuracy: 0.9947 - 140s/epoch - 583ms/step
# Epoch 94/100
# 240/240 - 143s - loss: 0.0059 - accuracy: 0.9982 - val_loss: 0.0359 - val_accuracy: 0.9941 - 143s/epoch - 596ms/step
# Epoch 95/100
# 240/240 - 142s - loss: 0.0036 - accuracy: 0.9987 - val_loss: 0.0419 - val_accuracy: 0.9946 - 142s/epoch - 593ms/step
# Epoch 96/100
# 240/240 - 144s - loss: 0.0049 - accuracy: 0.9984 - val_loss: 0.0401 - val_accuracy: 0.9950 - 144s/epoch - 599ms/step
# Epoch 97/100
# 240/240 - 138s - loss: 0.0040 - accuracy: 0.9987 - val_loss: 0.0416 - val_accuracy: 0.9940 - 138s/epoch - 576ms/step
# Epoch 98/100
# 240/240 - 138s - loss: 0.0053 - accuracy: 0.9983 - val_loss: 0.0346 - val_accuracy: 0.9944 - 138s/epoch - 575ms/step
# Epoch 99/100
# 240/240 - 135s - loss: 0.0052 - accuracy: 0.9983 - val_loss: 0.0361 - val_accuracy: 0.9948 - 135s/epoch - 565ms/step
# Epoch 100/100
# 240/240 - 134s - loss: 0.0054 - accuracy: 0.9982 - val_loss: 0.0365 - val_accuracy: 0.9956 - 134s/epoch - 559ms/step

# %%
print_metrics_base(model_conv)
# Out:
# Метрики обучения:
# ---------------------------------------------------------
# Максимальная точность на тренировочном наборе: 0.9987
# Минимальная потеря на тренировочном наборе: 0.0036
# Максимальная точность на валидационном наборе: 0.9956
# Минимальная потеря на валидационном наборе: 0.0244
# Наивысшая точность достигнута на эпохе: 88

# %%
def conv(model, path):
    predict_conv(model, path)

# %%
import pickle

# Сохранение модели в файл
filename = 'model_rupasov.pkl'
with open(filename, 'wb') as file:
    pickle.dump(model, file)

# %%
# Сохранение модели в файл
filename = 'model_conv_rupasov.pkl'
with open(filename, 'wb') as file:
    pickle.dump(model_conv, file)

# %%
# Загрузка модели из файла
filename = 'model_rupasov.pkl'
with open(filename, 'rb') as file:
    model111 = pickle.load(file)

# %%
# Загрузка модели из файла
filename = 'model_conv_rupasov.pkl'
with open(filename, 'rb') as file:
    model222 = pickle.load(file)

# %%
import os

# Укажите путь к папке, которую вы хотите просканировать
folder_path = '/content/'

# Допустимые расширения файлов изображений
image_extensions = ['.jpg', '.jpeg', '.png']

# Цикл для перебора всех файлов в папке
for root, dirs, files in os.walk(folder_path):
    for file_name in files:
        # Полный путь к файлу
        file_path = os.path.join(root, file_name)

        # Получение расширения файла
        file_extension = os.path.splitext(file_name)[1].lower()

        # Проверка, является ли файл изображением
        if file_extension in image_extensions:
            print(f"-------{file_path}---------")
            dense(model111, file_path)
# Out:
# -------/content/num5_1.png---------
# shape: (1, 784)
# 1/1 [==============================] - 0s 85ms/step
# Предсказанное число  5
# -------/content/num0_1.png---------
# shape: (1, 784)
# 1/1 [==============================] - 0s 32ms/step
# Предсказанное число  0
# -------/content/num4.png---------
# shape: (1, 784)
# 1/1 [==============================] - 0s 34ms/step
# Предсказанное число  4
# -------/content/num7_3.png---------
# shape: (1, 784)
# 1/1 [==============================] - 0s 32ms/step
# Предсказанное число  6
# -------/content/num1_1.png---------
# shape: (1, 784)
# 1/1 [==============================] - 0s 35ms/step
# Предсказанное число  1
# -------/content/num5_3.png---------
# shape: (1, 784)
# 1/1 [==============================] - 0s 34ms/step
# Предсказанное число  5
# -------/content/num8_1.png---------
# shape: (1, 784)
# 1/1 [==============================] - 0s 41ms/step
# Предсказанное число  2
# -------/content/num6_1.png---------
# shape: (1, 784)
# 1/1 [==============================] - 0s 34ms/step
# Предсказанное число  8
# -------/content/num3_1.png---------
# shape: (1, 784)
# 1/1 [==============================] - 0s 41ms/step
# Предсказанное число  3
# -------/content/num9_1.png---------
# shape: (1, 784)
# 1/1 [==============================] - 0s 38ms/step
# Предсказанное число  2
# -------/content/num7_2.png---------
# shape: (1, 784)
# 1/1 [==============================] - 0s 26ms/step
# Предсказанное число  3
# -------/content/num2_1.png---------
# shape: (1, 784)
# 1/1 [==============================] - 0s 25ms/step
# Предсказанное число  3
# -------/content/num5_2.png---------
# shape: (1, 784)
# 1/1 [==============================] - 0s 23ms/step
# Предсказанное число  5
# -------/content/num6_2.png---------
# shape: (1, 784)
# 1/1 [==============================] - 0s 23ms/step
# Предсказанное число  5
# -------/content/num7_1.png---------
# shape: (1, 784)
# 1/1 [==============================] - 0s 26ms/step
# Предсказанное число  3

# %%
import os

# Укажите путь к папке, которую вы хотите просканировать
folder_path = '/content/'

# Допустимые расширения файлов изображений
image_extensions = ['.jpg', '.jpeg', '.png']

# Цикл для перебора всех файлов в папке
for root, dirs, files in os.walk(folder_path):
    for file_name in files:
        # Полный путь к файлу
        file_path = os.path.join(root, file_name)

        # Получение расширения файла
        file_extension = os.path.splitext(file_name)[1].lower()

        # Проверка, является ли файл изображением
        if file_extension in image_extensions:
            print(f"-------{file_path}---------")
            conv(model222, file_path)
# Out:
# -------/content/num5_1.png---------
# shape: (1, 28, 28, 1)
# 1/1 [==============================] - 0s 112ms/step
# Предсказанное число (Dense Model): 5
# -------/content/num0_1.png---------
# shape: (1, 28, 28, 1)
# 1/1 [==============================] - 0s 26ms/step
# Предсказанное число (Dense Model): 0
# -------/content/num4.png---------
# shape: (1, 28, 28, 1)
# 1/1 [==============================] - 0s 23ms/step
# Предсказанное число (Dense Model): 4
# -------/content/num7_3.png---------
# shape: (1, 28, 28, 1)
# 1/1 [==============================] - 0s 22ms/step
# Предсказанное число (Dense Model): 3
# -------/content/num1_1.png---------
# shape: (1, 28, 28, 1)
# 1/1 [==============================] - 0s 23ms/step
# Предсказанное число (Dense Model): 1
# -------/content/num5_3.png---------
# shape: (1, 28, 28, 1)
# 1/1 [==============================] - 0s 23ms/step
# Предсказанное число (Dense Model): 5
# -------/content/num8_1.png---------
# shape: (1, 28, 28, 1)
# 1/1 [==============================] - 0s 26ms/step
# Предсказанное число (Dense Model): 8
# -------/content/num6_1.png---------
# shape: (1, 28, 28, 1)
# 1/1 [==============================] - 0s 22ms/step
# Предсказанное число (Dense Model): 6
# -------/content/num3_1.png---------
# shape: (1, 28, 28, 1)
# 1/1 [==============================] - 0s 27ms/step
# Предсказанное число (Dense Model): 3
# -------/content/num9_1.png---------
# shape: (1, 28, 28, 1)
# 1/1 [==============================] - 0s 26ms/step
# Предсказанное число (Dense Model): 2
# -------/content/num7_2.png---------
# shape: (1, 28, 28, 1)
# 1/1 [==============================] - 0s 24ms/step
# Предсказанное число (Dense Model): 7
# -------/content/num2_1.png---------
# shape: (1, 28, 28, 1)
# 1/1 [==============================] - 0s 25ms/step
# Предсказанное число (Dense Model): 2
# -------/content/num5_2.png---------
# shape: (1, 28, 28, 1)
# 1/1 [==============================] - 0s 24ms/step
# Предсказанное число (Dense Model): 5
# -------/content/num6_2.png---------
# shape: (1, 28, 28, 1)
# 1/1 [==============================] - 0s 24ms/step
# Предсказанное число (Dense Model): 0
# -------/content/num7_1.png---------
# shape: (1, 28, 28, 1)
# 1/1 [==============================] - 0s 36ms/step
# Предсказанное число (Dense Model): 7
